# %%
import sys
import os
import platform
import psutil
from importlib.metadata import distributions  # New way to list libraries

# Display Python version
print(f"Python version: {sys.version}")

# Display the location of the Python executable
print(f"Python executable location: {os.path.abspath(sys.executable)}")

# Display the operating system and architecture
print(f"Operating System: {platform.system()} {platform.release()} ({platform.architecture()[0]})")

# Display the installed libraries and their versions
print("\nInstalled libraries:")
for dist in distributions():
    print(f"{dist.metadata['Name']}=={dist.version}")

# Display CPU information
cpu_count = psutil.cpu_count(logical=False)  # Physical cores
print(f"\nCPU: {cpu_count} physical cores")

# Display Memory information
memory = psutil.virtual_memory()
print(f"Total RAM: {memory.total / (1024 ** 3):.2f} GB")
# Out:
# Python version: 3.13.1 (tags/v3.13.1:0671451, Dec  3 2024, 19:06:28) [MSC v.1942 64 bit (AMD64)]
# Python executable location: C:\Users\Propriétaire\sentiment_project\sentiment\.venv\Scripts\python.exe
# Operating System: Windows 10 (64bit)
#
# Installed libraries:
# alembic==1.14.0
# aniso8601==7.0.0
# anyio==4.7.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==3.0.0
# async-lru==2.0.4
# attrs==24.3.0
# babel==2.16.0
# beautifulsoup4==4.12.3
# bleach==6.2.0
# blinker==1.9.0
# cachetools==5.5.0
# certifi==2024.12.14
# cffi==1.17.1
# charset-normalizer==3.4.1
# click==8.1.8
# cloudpickle==3.1.0
# colorama==0.4.6
# comm==0.2.2
# contourpy==1.3.1
# cycler==0.12.1
# databricks-sdk==0.40.0
# debugpy==1.8.11
# decorator==5.1.1
# defusedxml==0.7.1
# Deprecated==1.2.15
# docker==7.1.0
# executing==2.1.0
# fastjsonschema==2.21.1
# Flask==3.1.0
# fonttools==4.55.3
# fqdn==1.4.0
# gitdb==4.0.12
# GitPython==3.1.44
# google-auth==2.37.0
# graphene==2.1.9
# ...

# %%
# Ignore Python compiled files
__pycache__/
*.pyc
*.pyo
# Ignore Poetry virtual environment
.poetry/
# Ignore Jupyter Notebook checkpoints
.ipynb_checkpoints/
# Ignore environment-specific files
.env
.envrc
# Ignore MLflow logs and artifacts
mlruns/
# Ignore system-specific files
